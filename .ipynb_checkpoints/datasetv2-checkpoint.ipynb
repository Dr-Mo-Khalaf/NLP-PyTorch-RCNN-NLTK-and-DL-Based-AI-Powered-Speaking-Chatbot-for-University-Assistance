# %%
import json
import numpy as np
import nltk
from nltk_utils import tokenize_fn, stem_fn, lemmatize_fn ,bag_of_words

import torch
from torch.utils.data import Dataset, DataLoader
from classes import createChatDataset
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\University\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\University\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\University\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\University\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer
import string
from nltk.corpus import stopwords
import re

# Download necessary NLTK data if not already downloaded
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Define stop words using nltk's stopword list
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)

# The ignore list containing words to exclude
ignore_list = [ ]

# Function to clean contractions
def clean_contractions(word):
    return re.sub(r"['’]s$", "", word).replace("n't", "")

# Function to tokenize and lemmatize while filtering
def preprocess_words(pattern, stop_words, punctuation, ignore_list):
    # all_words = []
    # for pattern in patterns:
    words = nltk.word_tokenize(pattern.lower())  # Tokenize the sentence
    print(words)
    words = [clean_contractions(w) for w in words]  # Clean contractions like 's and n't
    words = [lemmatizer.lemmatize(w) for w in words]  # Lemmatize words
    words = [w for w in words if w not in stop_words and w not in punctuation and w not in ignore_list]  # Filter unwanted words
    all_words.extend(words)
    return sorted(set(all_words))  # Return unique words
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\University\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\University\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\University\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open('intents2.json', "r") as f:
    all_intents = json.load(f)

# %%
# import string
all_words = []
tags = []
xy = []
# print(all_intents)
for intent in all_intents["intents"] :
    tag = intent['tag']
    tags.append(tag)
    for pattern in intent['patterns']:
        w = preprocess_words(patterns=pattern , stop_words= stop_words ,
                             punctuation=punctuation , ignore_list=ignore_list)
        print(w)
        all_words.extend(w)
        xy.append((w,tag))
# Out:
# ['h']
# ['e']
# ['l']
# ['l']
# ['o']
# ['e', 'h', 'l']
# ['h']
# ['i']
# ['h']
# ['h']
# ['e']
# ['y']
# []
# ['t']
# ['h']
# ['e']
# ['r']
# ['e']
# ['e', 'h', 'r']
# ['g']
# ['o']
# ['o']
# ['d']
# []
# ['m']
# ['o']
# ['r']
# ['n']
# ['i']
# ['n']
# ['g']
# ['g', 'n', 'r']
# ['h']
# ['o']
# ['w']
# ["'"]
# ['s']
# []
# ['i']
# ['t']
# []
# ['g']
# ['o']
# ['i']
# ['n']
# ['g']
# ['?']
# ['g', 'h', 'n', 'w']
# ['h']
# ['i']
# [',']
# []
# ['h']
# ['o']
# ['w']
# []
# ['a']
# ['r']
# ['e']
# []
# ['y']
# ['o']
# ['u']
# ['?']
# ['e', 'h', 'r', 'u', 'w']
# ['h']
# ['e']
# ['l']
# ['l']
# ['o']
# [',']
# []
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['h']
# ['e']
# ['l']
# ['p']
# []
# ['y']
# ['o']
# ['u']
# []
# ['t']
# ['o']
# ['d']
# ['a']
# ['y']
# ['?']
# ['c', 'e', 'h', 'l', 'n', 'p', 'u', 'w']
# ['g']
# ['o']
# ['o']
# ['d']
# []
# ['d']
# ['a']
# ['y']
# ['!']
# ['g']
# ['g']
# ['r']
# ['e']
# ['e']
# ['t']
# ['i']
# ['n']
# ['g']
# ['s']
# ['e', 'g', 'n', 'r']
# ['h']
# ['e']
# ['y']
# [',']
# []
# ['i']
# ['s']
# []
# ['a']
# ['n']
# ['y']
# ['o']
# ['n']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# ['r']
# ['e']
# ['?']
# ['e', 'h', 'n', 'r']
# ['w']
# ['h']
# ['a']
# ['t']
# ["'"]
# ['s']
# []
# ['u']
# ['p']
# ['?']
# ['h', 'p', 'u', 'w']
# ['y']
# ['o']
# ['!']
# []
# ['g']
# ['o']
# ['o']
# ['d']
# ['b']
# ['y']
# ['e']
# ['b', 'e', 'g']
# ['s']
# ['e']
# ['e']
# []
# ['y']
# ['o']
# ['u']
# []
# ['l']
# ['a']
# ['t']
# ['e']
# ['r']
# ['e', 'l', 'r', 'u']
# ['t']
# ['h']
# ['a']
# ['n']
# ['k']
# ['s']
# []
# ['f']
# ['o']
# ['r']
# []
# ['t']
# ['h']
# ['e']
# []
# ['h']
# ['e']
# ['l']
# ['p']
# ['e', 'f', 'h', 'k', 'l', 'n', 'p', 'r']
# ['b']
# ['y']
# ['e']
# ['b', 'e']
# ['t']
# ['a']
# ['k']
# ['e']
# []
# ['c']
# ['a']
# ['r']
# ['e']
# ['c', 'e', 'k', 'r']
# ['c']
# ['a']
# ['t']
# ['c']
# ['h']
# []
# ['y']
# ['o']
# ['u']
# []
# ['l']
# ['a']
# ['t']
# ['e']
# ['r']
# ['c', 'e', 'h', 'l', 'r', 'u']
# ['f']
# ['a']
# ['r']
# ['e']
# ['w']
# ['e']
# ['l']
# ['l']
# ['e', 'f', 'l', 'r', 'w']
# ['s']
# ['e']
# ['e']
# []
# ['y']
# ['o']
# ['u']
# []
# ['s']
# ['o']
# ['o']
# ['n']
# ['e', 'n', 'u']
# ['h']
# ['o']
# ['w']
# []
# ['d']
# ['o']
# []
# ['i']
# []
# ['c']
# ['h']
# ['o']
# ['o']
# ['s']
# ['e']
# []
# ['a']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['y']
# ['?']
# ['c', 'e', 'f', 'h', 'l', 'u', 'w']
# ['w']
# ['h']
# ['i']
# ['c']
# ['h']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['y']
# []
# ['s']
# ['h']
# ['o']
# ['u']
# ['l']
# ['d']
# []
# ['i']
# []
# ['s']
# ['e']
# ['l']
# ['e']
# ['c']
# ['t']
# ['?']
# ['c', 'e', 'f', 'h', 'l', 'u', 'w']
# ['i']
# []
# ['d']
# ['o']
# ['n']
# ["'"]
# ['t']
# []
# ['k']
# ['n']
# ['o']
# ['w']
# []
# ['w']
# ['h']
# ['i']
# ['c']
# ['h']
# []
# ['d']
# ['e']
# ['p']
# ['a']
# ['r']
# ['t']
# ['m']
# ['e']
# ['n']
# ['t']
# []
# ['t']
# ['o']
# []
# ['j']
# ['o']
# ['i']
# ['n']
# ['c', 'e', 'h', 'j', 'k', 'n', 'p', 'r', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['d']
# ['i']
# ['f']
# ['f']
# ['e']
# ['r']
# ['e']
# ['n']
# ['t']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['i']
# ['e']
# ['s']
# []
# ['a']
# ['v']
# ['a']
# ['i']
# ['l']
# ['a']
# ['b']
# ['l']
# ['e']
# ['?']
# ['b', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'v', 'w']
# ['w']
# ['h']
# ['i']
# ['c']
# ['h']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['y']
# []
# ['i']
# ['s']
# []
# ['b']
# ['e']
# ['s']
# ['t']
# []
# ['f']
# ['o']
# ['r']
# []
# ['m']
# ['e']
# ['?']
# ['b', 'c', 'e', 'f', 'h', 'l', 'r', 'u', 'w']
# ['c']
# ['a']
# ['n']
# []
# ['y']
# ['o']
# ['u']
# []
# ['h']
# ['e']
# ['l']
# ['p']
# []
# ['m']
# ['e']
# []
# ['c']
# ['h']
# ['o']
# ['o']
# ['s']
# ['e']
# []
# ['a']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['y']
# ['?']
# ['c', 'e', 'f', 'h', 'l', 'n', 'p', 'u']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['o']
# ['p']
# ['t']
# ['i']
# ['o']
# ['n']
# ['s']
# []
# ['f']
# ['o']
# ['r']
# []
# ['s']
# ['e']
# ['l']
# ['e']
# ['c']
# ['t']
# ['i']
# ['n']
# ['g']
# []
# ['a']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['y']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'l', 'n', 'p', 'r', 'u', 'w']
# ['h']
# ['o']
# ['w']
# []
# ['d']
# ['o']
# []
# ['i']
# []
# ['s']
# ['e']
# ['l']
# ['e']
# ['c']
# ['t']
# []
# ['m']
# ['y']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['y']
# []
# ['f']
# ['o']
# ['r']
# []
# ['t']
# ['h']
# ['e']
# []
# ['u']
# ['n']
# ['i']
# ['v']
# ['e']
# ['r']
# ['s']
# ['i']
# ['t']
# ['y']
# ['?']
# ['c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'v', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['f']
# ['a']
# ['c']
# ['t']
# ['o']
# ['r']
# ['s']
# []
# ['s']
# ['h']
# ['o']
# ['u']
# ['l']
# ['d']
# []
# ['i']
# []
# ['c']
# ['o']
# ['n']
# ['s']
# ['i']
# ['d']
# ['e']
# ['r']
# []
# ['f']
# ['o']
# ['r']
# []
# ['s']
# ['e']
# ['l']
# ['e']
# ['c']
# ['t']
# ['i']
# ['n']
# ['g']
# []
# ['a']
# []
# ['f']
# ['a']
# ['c']
# ['u']
# ['l']
# ['t']
# ['y']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'l', 'n', 'r', 'u', 'w']
# ['i']
# []
# ['p']
# ['r']
# ['e']
# ['f']
# ['e']
# ['r']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['l']
# ['e']
# ['a']
# ['r']
# ['n']
# ['i']
# ['n']
# ['g']
# ['c', 'e', 'f', 'g', 'l', 'n', 'p', 'r']
# ['i']
# []
# ['l']
# ['o']
# ['v']
# ['e']
# []
# ['h']
# ['a']
# ['n']
# ['d']
# ['s']
# ['-']
# ['o']
# ['n']
# []
# ['w']
# ['o']
# ['r']
# ['k']
# ['e', 'h', 'k', 'l', 'n', 'r', 'v', 'w']
# ['i']
# []
# ['l']
# ['i']
# ['k']
# ['e']
# []
# ['c']
# ['r']
# ['e']
# ['a']
# ['t']
# ['i']
# ['v']
# ['e']
# []
# ['s']
# ['u']
# ['b']
# ['j']
# ['e']
# ['c']
# ['t']
# ['s']
# ['b', 'c', 'e', 'j', 'k', 'l', 'r', 'u', 'v']
# ['i']
# []
# ['e']
# ['n']
# ['j']
# ['o']
# ['y']
# []
# ['a']
# ['r']
# ['t']
# ['s']
# []
# ['a']
# ['n']
# ['d']
# []
# ['d']
# ['e']
# ['s']
# ['i']
# ['g']
# ['n']
# ['e', 'g', 'j', 'n', 'r']
# ['i']
# ["'"]
# ['m']
# []
# ['i']
# ['n']
# ['t']
# ['e']
# ['r']
# ['e']
# ['s']
# ['t']
# ['e']
# ['d']
# []
# ['i']
# ['n']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['s']
# ['k']
# ['i']
# ['l']
# ['l']
# ['s']
# ['c', 'e', 'k', 'l', 'n', 'p', 'r']
# ['i']
# []
# ['p']
# ['r']
# ['e']
# ['f']
# ['e']
# ['r']
# []
# ['t']
# ['h']
# ['e']
# ['o']
# ['r']
# ['e']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['i']
# ['e']
# ['s']
# ['c', 'e', 'f', 'h', 'l', 'p', 'r', 'u']
# ['i']
# []
# ['e']
# ['n']
# ['j']
# ['o']
# ['y']
# []
# ['b']
# ['u']
# ['i']
# ['l']
# ['d']
# ['i']
# ['n']
# ['g']
# []
# ['t']
# ['h']
# ['i']
# ['n']
# ['g']
# ['s']
# ['b', 'e', 'g', 'h', 'j', 'l', 'n', 'u']
# ['i']
# []
# ['w']
# ['a']
# ['n']
# ['t']
# []
# ['t']
# ['o']
# []
# ['d']
# ['o']
# []
# ['s']
# ['o']
# ['m']
# ['e']
# ['t']
# ['h']
# ['i']
# ['n']
# ['g']
# []
# ['c']
# ['r']
# ['e']
# ['a']
# ['t']
# ['i']
# ['v']
# ['e']
# ['c', 'e', 'g', 'h', 'n', 'r', 'v', 'w']
# ['i']
# []
# ['l']
# ['o']
# ['v']
# ['e']
# []
# ['w']
# ['o']
# ['r']
# ['k']
# ['i']
# ['n']
# ['g']
# []
# ['o']
# ['n']
# []
# ['r']
# ['e']
# ['a']
# ['l']
# ['-']
# ['w']
# ['o']
# ['r']
# ['l']
# ['d']
# []
# ['p']
# ['r']
# ['o']
# ['j']
# ['e']
# ['c']
# ['t']
# ['s']
# ['c', 'e', 'g', 'j', 'k', 'l', 'n', 'p', 'r', 'v', 'w']
# ['i']
# ["'"]
# ['m']
# []
# ['p']
# ['a']
# ['s']
# ['s']
# ['i']
# ['o']
# ['n']
# ['a']
# ['t']
# ['e']
# []
# ['a']
# ['b']
# ['o']
# ['u']
# ['t']
# []
# ['a']
# ['r']
# ['t']
# []
# ['a']
# ['n']
# ['d']
# []
# ['d']
# ['e']
# ['s']
# ['i']
# ['g']
# ['n']
# ['b', 'e', 'g', 'n', 'p', 'r', 'u']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# []
# ['d']
# ['o']
# []
# ['y']
# ['o']
# ['u']
# []
# ['o']
# ['f']
# ['f']
# ['e']
# ['r']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'l', 'p', 'r', 'u', 'w']
# ['t']
# ['e']
# ['l']
# ['l']
# []
# ['m']
# ['e']
# []
# ['a']
# ['b']
# ['o']
# ['u']
# ['t']
# []
# ['t']
# ['h']
# ['e']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['c']
# ['o']
# ['u']
# ['r']
# ['s']
# ['e']
# ['s']
# ['b', 'c', 'e', 'h', 'l', 'p', 'r', 'u']
# ['i']
# []
# ['a']
# ['m']
# []
# ['i']
# ['n']
# ['t']
# ['e']
# ['r']
# ['e']
# ['s']
# ['t']
# ['e']
# ['d']
# []
# ['i']
# ['n']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['l']
# ['e']
# ['a']
# ['r']
# ['n']
# ['i']
# ['n']
# ['g']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# ['c', 'e', 'g', 'l', 'n', 'p', 'r']
# ['w']
# ['h']
# ['i']
# ['c']
# ['h']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# []
# ['a']
# ['r']
# ['e']
# []
# ['h']
# ['a']
# ['n']
# ['d']
# ['s']
# ['-']
# ['o']
# ['n']
# ['?']
# ['c', 'e', 'g', 'h', 'n', 'p', 'r', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['b']
# ['e']
# ['s']
# ['t']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['c']
# ['o']
# ['u']
# ['r']
# ['s']
# ['e']
# ['s']
# []
# ['h']
# ['e']
# ['r']
# ['e']
# ['?']
# ['b', 'c', 'e', 'h', 'l', 'p', 'r', 'u', 'w']
# ['d']
# ['o']
# []
# ['y']
# ['o']
# ['u']
# []
# ['o']
# ['f']
# ['f']
# ['e']
# ['r']
# []
# ['e']
# ['n']
# ['g']
# ['i']
# ['n']
# ['e']
# ['e']
# ['r']
# ['i']
# ['n']
# ['g']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# ['?']
# ['e', 'f', 'g', 'n', 'p', 'r', 'u']
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['c']
# ['o']
# ['m']
# ['p']
# ['u']
# ['t']
# ['e']
# ['r']
# []
# ['s']
# ['c']
# ['i']
# ['e']
# ['n']
# ['c']
# ['e']
# []
# ['h']
# ['e']
# ['r']
# ['e']
# ['?']
# ['c', 'e', 'h', 'n', 'p', 'r', 'u']
# ['w']
# ['h']
# ['i']
# ['c']
# ['h']
# []
# ['c']
# ['o']
# ['u']
# ['r']
# ['s']
# ['e']
# ['s']
# []
# ['a']
# ['r']
# ['e']
# []
# ['b']
# ['e']
# ['s']
# ['t']
# []
# ['f']
# ['o']
# ['r']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['e']
# ['x']
# ['p']
# ['e']
# ['r']
# ['i']
# ['e']
# ['n']
# ['c']
# ['e']
# ['?']
# ['b', 'c', 'e', 'f', 'h', 'l', 'n', 'p', 'r', 'u', 'w', 'x']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['t']
# ['o']
# ['p']
# []
# ['p']
# ['r']
# ['a']
# ['c']
# ['t']
# ['i']
# ['c']
# ['a']
# ['l']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# []
# ['f']
# ['o']
# ['r']
# []
# ['h']
# ['a']
# ['n']
# ['d']
# ['s']
# ['-']
# ['o']
# ['n']
# []
# ['l']
# ['e']
# ['a']
# ['r']
# ['n']
# ['i']
# ['n']
# ['g']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'l', 'n', 'p', 'r', 'w']
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# ['r']
# ['e']
# []
# ['a']
# ['n']
# ['y']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# []
# ['f']
# ['o']
# ['c']
# ['u']
# ['s']
# ['e']
# ['d']
# []
# ['o']
# ['n']
# []
# ['r']
# ['e']
# ['a']
# ['l']
# ['-']
# ['w']
# ['o']
# ['r']
# ['l']
# ['d']
# []
# ['s']
# ['k']
# ['i']
# ['l']
# ['l']
# ['s']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'k', 'l', 'n', 'p', 'r', 'u', 'w']
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['r']
# ['o']
# ['b']
# ['o']
# ['t']
# ['i']
# ['c']
# ['s']
# []
# ['o']
# ['r']
# []
# ['a']
# ['i']
# ['?']
# ['b', 'c', 'n', 'r', 'u']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# []
# ['e']
# ['m']
# ['p']
# ['h']
# ['a']
# ['s']
# ['i']
# ['z']
# ['e']
# []
# ['f']
# ['i']
# ['e']
# ['l']
# ['d']
# ['w']
# ['o']
# ['r']
# ['k']
# []
# ['a']
# ['n']
# ['d']
# []
# ['i']
# ['n']
# ['t']
# ['e']
# ['r']
# ['n']
# ['s']
# ['h']
# ['i']
# ['p']
# ['s']
# ['?']
# ['e', 'f', 'g', 'h', 'k', 'l', 'n', 'p', 'r', 'w', 'z']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['t']
# ['i']
# ['s']
# ['t']
# ['i']
# ['c']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# []
# ['d']
# ['o']
# []
# ['y']
# ['o']
# ['u']
# []
# ['h']
# ['a']
# ['v']
# ['e']
# ['?']
# ['c', 'e', 'g', 'h', 'p', 'r', 'u', 'v', 'w']
# ['i']
# []
# ['w']
# ['a']
# ['n']
# ['t']
# []
# ['t']
# ['o']
# []
# ['k']
# ['n']
# ['o']
# ['w']
# []
# ['a']
# ['b']
# ['o']
# ['u']
# ['t']
# []
# ['c']
# ['r']
# ['e']
# ['a']
# ['t']
# ['i']
# ['v']
# ['e']
# []
# ['c']
# ['o']
# ['u']
# ['r']
# ['s']
# ['e']
# ['s']
# ['b', 'c', 'e', 'k', 'n', 'r', 'u', 'v', 'w']
# ['t']
# ['e']
# ['l']
# ['l']
# []
# ['m']
# ['e']
# []
# ['a']
# ['b']
# ['o']
# ['u']
# ['t']
# []
# ['a']
# ['r']
# ['t']
# ['s']
# []
# ['a']
# ['n']
# ['d']
# []
# ['d']
# ['e']
# ['s']
# ['i']
# ['g']
# ['n']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# ['b', 'e', 'g', 'l', 'n', 'p', 'r', 'u']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['c']
# ['r']
# ['e']
# ['a']
# ['t']
# ['i']
# ['v']
# ['e']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# []
# ['a']
# ['v']
# ['a']
# ['i']
# ['l']
# ['a']
# ['b']
# ['l']
# ['e']
# ['?']
# ['b', 'c', 'e', 'g', 'h', 'l', 'p', 'r', 'v', 'w']
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['f']
# ['i']
# ['n']
# ['e']
# []
# ['a']
# ['r']
# ['t']
# ['s']
# []
# ['h']
# ['e']
# ['r']
# ['e']
# ['?']
# ['c', 'e', 'f', 'h', 'n', 'r', 'u']
# ['d']
# ['o']
# []
# ['y']
# ['o']
# ['u']
# []
# ['o']
# ['f']
# ['f']
# ['e']
# ['r']
# []
# ['g']
# ['r']
# ['a']
# ['p']
# ['h']
# ['i']
# ['c']
# []
# ['d']
# ['e']
# ['s']
# ['i']
# ['g']
# ['n']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'n', 'p', 'r', 'u']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['a']
# ['r']
# ['t']
# ['-']
# ['r']
# ['e']
# ['l']
# ['a']
# ['t']
# ['e']
# ['d']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['a']
# ['m']
# ['s']
# ['?']
# ['e', 'g', 'h', 'l', 'p', 'r', 'w']
# ['i']
# []
# ['w']
# ['a']
# ['n']
# ['t']
# []
# ['t']
# ['o']
# []
# ['p']
# ['u']
# ['r']
# ['s']
# ['u']
# ['e']
# []
# ['a']
# []
# ['c']
# ['a']
# ['r']
# ['e']
# ['e']
# ['r']
# []
# ['i']
# ['n']
# []
# ['d']
# ['e']
# ['s']
# ['i']
# ['g']
# ['n']
# ['c', 'e', 'g', 'n', 'p', 'r', 'u', 'w']
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['f']
# ['a']
# ['s']
# ['h']
# ['i']
# ['o']
# ['n']
# []
# ['d']
# ['e']
# ['s']
# ['i']
# ['g']
# ['n']
# []
# ['h']
# ['e']
# ['r']
# ['e']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'n', 'r', 'u']
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['m']
# ['a']
# ['n']
# ['a']
# ['g']
# ['e']
# []
# ['m']
# ['y']
# []
# ['t']
# ['i']
# ['m']
# ['e']
# []
# ['e']
# ['f']
# ['f']
# ['e']
# ['c']
# ['t']
# ['i']
# ['v']
# ['e']
# ['l']
# ['y']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'l', 'n', 'v', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['s']
# ['o']
# ['m']
# ['e']
# []
# ['g']
# ['o']
# ['o']
# ['d']
# []
# ['t']
# ['i']
# ['m']
# ['e']
# []
# ['m']
# ['a']
# ['n']
# ['a']
# ['g']
# ['e']
# ['m']
# ['e']
# ['n']
# ['t']
# []
# ['t']
# ['i']
# ['p']
# ['s']
# ['?']
# ['e', 'g', 'h', 'n', 'p', 'r', 'w']
# ['h']
# ['o']
# ['w']
# []
# ['d']
# ['o']
# []
# ['i']
# []
# ['b']
# ['a']
# ['l']
# ['a']
# ['n']
# ['c']
# ['e']
# []
# ['m']
# ['y']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['i']
# ['e']
# ['s']
# []
# ['a']
# ['n']
# ['d']
# []
# ['f']
# ['r']
# ['e']
# ['e']
# []
# ['t']
# ['i']
# ['m']
# ['e']
# ['?']
# ['b', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'w']
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['a']
# ['v']
# ['o']
# ['i']
# ['d']
# []
# ['p']
# ['r']
# ['o']
# ['c']
# ['r']
# ['a']
# ['s']
# ['t']
# ['i']
# ['n']
# ['a']
# ['t']
# ['i']
# ['o']
# ['n']
# ['?']
# ['c', 'h', 'n', 'p', 'r', 'v', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['i']
# ['s']
# []
# ['t']
# ['h']
# ['e']
# []
# ['b']
# ['e']
# ['s']
# ['t']
# []
# ['w']
# ['a']
# ['y']
# []
# ['t']
# ['o']
# []
# ['o']
# ['r']
# ['g']
# ['a']
# ['n']
# ['i']
# ['z']
# ['e']
# []
# ['m']
# ['y']
# []
# ['d']
# ['a']
# ['y']
# ['?']
# ['b', 'e', 'g', 'h', 'n', 'r', 'w', 'z']
# ['c']
# ['a']
# ['n']
# []
# ['y']
# ['o']
# ['u']
# []
# ['g']
# ['i']
# ['v']
# ['e']
# []
# ['m']
# ['e']
# []
# ['t']
# ['i']
# ['p']
# ['s']
# []
# ['f']
# ['o']
# ['r']
# []
# ['b']
# ['e']
# ['t']
# ['t']
# ['e']
# ['r']
# []
# ['t']
# ['i']
# ['m']
# ['e']
# []
# ['m']
# ['a']
# ['n']
# ['a']
# ['g']
# ['e']
# ['m']
# ['e']
# ['n']
# ['t']
# ['?']
# ['b', 'c', 'e', 'f', 'g', 'n', 'p', 'r', 'u', 'v']
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['w']
# ['i']
# ['t']
# ['h']
# ['o']
# ['u']
# ['t']
# []
# ['g']
# ['e']
# ['t']
# ['t']
# ['i']
# ['n']
# ['g']
# []
# ['d']
# ['i']
# ['s']
# ['t']
# ['r']
# ['a']
# ['c']
# ['t']
# ['e']
# ['d']
# ['?']
# ['c', 'e', 'g', 'h', 'n', 'r', 'u', 'w']
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['b']
# ['e']
# ['t']
# ['t']
# ['e']
# ['r']
# ['?']
# ['b', 'c', 'e', 'h', 'n', 'r', 'u', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['b']
# ['e']
# ['s']
# ['t']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['t']
# ['e']
# ['c']
# ['h']
# ['n']
# ['i']
# ['q']
# ['u']
# ['e']
# ['s']
# ['?']
# ['b', 'c', 'e', 'h', 'n', 'q', 'r', 'u', 'w']
# ['h']
# ['o']
# ['w']
# []
# ['d']
# ['o']
# []
# ['i']
# []
# ['i']
# ['m']
# ['p']
# ['r']
# ['o']
# ['v']
# ['e']
# []
# ['m']
# ['y']
# []
# ['f']
# ['o']
# ['c']
# ['u']
# ['s']
# []
# ['w']
# ['h']
# ['i']
# ['l']
# ['e']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# ['i']
# ['n']
# ['g']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'l', 'n', 'p', 'r', 'u', 'v', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['i']
# ['s']
# []
# ['t']
# ['h']
# ['e']
# []
# ['m']
# ['o']
# ['s']
# ['t']
# []
# ['e']
# ['f']
# ['f']
# ['e']
# ['c']
# ['t']
# ['i']
# ['v']
# ['e']
# []
# ['w']
# ['a']
# ['y']
# []
# ['t']
# ['o']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['f']
# ['o']
# ['r']
# []
# ['e']
# ['x']
# ['a']
# ['m']
# ['s']
# ['?']
# ['c', 'e', 'f', 'h', 'r', 'u', 'v', 'w', 'x']
# ['c']
# ['a']
# ['n']
# []
# ['y']
# ['o']
# ['u']
# []
# ['s']
# ['h']
# ['a']
# ['r']
# ['e']
# []
# ['s']
# ['o']
# ['m']
# ['e']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['s']
# ['t']
# ['r']
# ['a']
# ['t']
# ['e']
# ['g']
# ['i']
# ['e']
# ['s']
# ['?']
# ['c', 'e', 'g', 'h', 'n', 'r', 'u']
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['r']
# ['e']
# ['m']
# ['e']
# ['m']
# ['b']
# ['e']
# ['r']
# []
# ['m']
# ['o']
# ['r']
# ['e']
# []
# ['d']
# ['u']
# ['r']
# ['i']
# ['n']
# ['g']
# []
# ['e']
# ['x']
# ['a']
# ['m']
# ['s']
# ['?']
# ['b', 'c', 'e', 'g', 'h', 'n', 'r', 'u', 'w', 'x']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# []
# ['b']
# ['e']
# ['s']
# ['t']
# []
# ['m']
# ['e']
# ['t']
# ['h']
# ['o']
# ['d']
# ['s']
# []
# ['f']
# ['o']
# ['r']
# []
# ['l']
# ['e']
# ['a']
# ['r']
# ['n']
# ['i']
# ['n']
# ['g']
# []
# ['e']
# ['f']
# ['f']
# ['i']
# ['c']
# ['i']
# ['e']
# ['n']
# ['t']
# ['l']
# ['y']
# ['?']
# ['b', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'r', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['i']
# ['s']
# []
# ['t']
# ['h']
# ['e']
# []
# ['b']
# ['e']
# ['s']
# ['t']
# []
# ['t']
# ['i']
# ['m']
# ['e']
# []
# ['t']
# ['o']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# ['?']
# ['b', 'e', 'h', 'u', 'w']
# ['w']
# ['h']
# ['e']
# ['n']
# []
# ['s']
# ['h']
# ['o']
# ['u']
# ['l']
# ['d']
# []
# ['i']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['f']
# ['o']
# ['r']
# []
# ['e']
# ['x']
# ['a']
# ['m']
# ['s']
# ['?']
# ['e', 'f', 'h', 'l', 'n', 'r', 'u', 'w', 'x']
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['o']
# ['p']
# ['t']
# ['i']
# ['m']
# ['i']
# ['z']
# ['e']
# []
# ['m']
# ['y']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['s']
# ['c']
# ['h']
# ['e']
# ['d']
# ['u']
# ['l']
# ['e']
# ['?']
# ['c', 'e', 'h', 'l', 'n', 'p', 'u', 'w', 'z']
# ['i']
# ['s']
# []
# ['i']
# ['t']
# []
# ['b']
# ['e']
# ['t']
# ['t']
# ['e']
# ['r']
# []
# ['t']
# ['o']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# []
# ['a']
# ['t']
# []
# ['n']
# ['i']
# ['g']
# ['h']
# ['t']
# []
# ['o']
# ['r']
# []
# ['d']
# ['u']
# ['r']
# ['i']
# ['n']
# ['g']
# []
# ['t']
# ['h']
# ['e']
# []
# ['d']
# ['a']
# ['y']
# ['?']
# ['b', 'e', 'g', 'h', 'n', 'r', 'u']
# ['w']
# ['h']
# ['e']
# ['n']
# []
# ['i']
# ['s']
# []
# ['t']
# ['h']
# ['e']
# []
# ['i']
# ['d']
# ['e']
# ['a']
# ['l']
# []
# ['t']
# ['i']
# ['m']
# ['e']
# []
# ['f']
# ['o']
# ['r']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# ['i']
# ['n']
# ['g']
# ['?']
# ['e', 'f', 'g', 'h', 'l', 'n', 'r', 'u', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['t']
# ['i']
# ['m']
# ['e']
# []
# ['s']
# ['h']
# ['o']
# ['u']
# ['l']
# ['d']
# []
# ['i']
# []
# ['s']
# ['t']
# ['a']
# ['r']
# ['t']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# ['i']
# ['n']
# ['g']
# ['?']
# ['e', 'g', 'h', 'l', 'n', 'r', 'u', 'w']
# ['i']
# ['s']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['y']
# ['i']
# ['n']
# ['g']
# []
# ['a']
# ['t']
# []
# ['n']
# ['i']
# ['g']
# ['h']
# ['t']
# []
# ['m']
# ['o']
# ['r']
# ['e']
# []
# ['e']
# ['f']
# ['f']
# ['e']
# ['c']
# ['t']
# ['i']
# ['v']
# ['e']
# ['?']
# ['c', 'e', 'f', 'g', 'h', 'n', 'r', 'u', 'v']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['e']
# ['n']
# ['t']
# []
# ['s']
# ['u']
# ['p']
# ['p']
# ['o']
# ['r']
# ['t']
# []
# ['s']
# ['e']
# ['r']
# ['v']
# ['i']
# ['c']
# ['e']
# ['s']
# []
# ['a']
# ['r']
# ['e']
# []
# ['a']
# ['v']
# ['a']
# ['i']
# ['l']
# ['a']
# ['b']
# ['l']
# ['e']
# ['?']
# ['b', 'c', 'e', 'h', 'l', 'n', 'p', 'r', 'u', 'v', 'w']
# ['h']
# ['o']
# ['w']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['g']
# ['e']
# ['t']
# []
# ['a']
# ['c']
# ['a']
# ['d']
# ['e']
# ['m']
# ['i']
# ['c']
# []
# ['h']
# ['e']
# ['l']
# ['p']
# ['?']
# ['c', 'e', 'g', 'h', 'l', 'n', 'p', 'w']
# ['a']
# ['r']
# ['e']
# []
# ['t']
# ['h']
# ['e']
# ['r']
# ['e']
# []
# ['c']
# ['o']
# ['u']
# ['n']
# ['s']
# ['e']
# ['l']
# ['o']
# ['r']
# ['s']
# []
# ['f']
# ['o']
# ['r']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['e']
# ['n']
# ['t']
# ['s']
# ['?']
# ['c', 'e', 'f', 'h', 'l', 'n', 'r', 'u']
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['g']
# ['e']
# ['t']
# []
# ['h']
# ['e']
# ['l']
# ['p']
# []
# ['w']
# ['i']
# ['t']
# ['h']
# []
# ['m']
# ['e']
# ['n']
# ['t']
# ['a']
# ['l']
# []
# ['h']
# ['e']
# ['a']
# ['l']
# ['t']
# ['h']
# ['?']
# ['c', 'e', 'g', 'h', 'l', 'n', 'p', 'w']
# ['w']
# ['h']
# ['e']
# ['r']
# ['e']
# []
# ['c']
# ['a']
# ['n']
# []
# ['i']
# []
# ['f']
# ['i']
# ['n']
# ['d']
# []
# ['a']
# ['c']
# ['a']
# ['d']
# ['e']
# ['m']
# ['i']
# ['c']
# []
# ['a']
# ['d']
# ['v']
# ['i']
# ['s']
# ['o']
# ['r']
# ['s']
# ['?']
# ['c', 'e', 'f', 'h', 'n', 'r', 'v', 'w']
# ['w']
# ['h']
# ['a']
# ['t']
# []
# ['s']
# ['e']
# ['r']
# ['v']
# ['i']
# ['c']
# ['e']
# ['s']
# []
# ['a']
# ['r']
# ['e']
# []
# ['a']
# ['v']
# ['a']
# ['i']
# ['l']
# ['a']
# ['b']
# ['l']
# ['e']
# []
# ['f']
# ['o']
# ['r']
# []
# ['s']
# ['t']
# ['u']
# ['d']
# ['e']
# ['n']
# ['t']
# ['s']
# []
# ['i']
# ['n']
# []
# ['n']
# ['e']
# ['e']
# ['d']
# ['?']
# ['b', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'v', 'w']

# %%
print(all_words)
# Out:
# ['e', 'h', 'l', 'h', 'e', 'h', 'r', 'g', 'n', 'r', 'g', 'h', 'n', 'w', 'e', 'h', 'r', 'u', 'w', 'c', 'e', 'h', 'l', 'n', 'p', 'u', 'w', 'g', 'e', 'g', 'n', 'r', 'e', 'h', 'n', 'r', 'h', 'p', 'u', 'w', 'b', 'e', 'g', 'e', 'l', 'r', 'u', 'e', 'f', 'h', 'k', 'l', 'n', 'p', 'r', 'b', 'e', 'c', 'e', 'k', 'r', 'c', 'e', 'h', 'l', 'r', 'u', 'e', 'f', 'l', 'r', 'w', 'e', 'n', 'u', 'c', 'e', 'f', 'h', 'l', 'u', 'w', 'c', 'e', 'f', 'h', 'l', 'u', 'w', 'c', 'e', 'h', 'j', 'k', 'n', 'p', 'r', 'w', 'b', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'v', 'w', 'b', 'c', 'e', 'f', 'h', 'l', 'r', 'u', 'w', 'c', 'e', 'f', 'h', 'l', 'n', 'p', 'u', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'p', 'r', 'u', 'w', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'v', 'w', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'r', 'u', 'w', 'c', 'e', 'f', 'g', 'l', 'n', 'p', 'r', 'e', 'h', 'k', 'l', 'n', 'r', 'v', 'w', 'b', 'c', 'e', 'j', 'k', 'l', 'r', 'u', 'v', 'e', 'g', 'j', 'n', 'r', 'c', 'e', 'k', 'l', 'n', 'p', 'r', 'c', 'e', 'f', 'h', 'l', 'p', 'r', 'u', 'b', 'e', 'g', 'h', 'j', 'l', 'n', 'u', 'c', 'e', 'g', 'h', 'n', 'r', 'v', 'w', 'c', 'e', 'g', 'j', 'k', 'l', 'n', 'p', 'r', 'v', 'w', 'b', 'e', 'g', 'n', 'p', 'r', 'u', 'c', 'e', 'f', 'g', 'h', 'l', 'p', 'r', 'u', 'w', 'b', 'c', 'e', 'h', 'l', 'p', 'r', 'u', 'c', 'e', 'g', 'l', 'n', 'p', 'r', 'c', 'e', 'g', 'h', 'n', 'p', 'r', 'w', 'b', 'c', 'e', 'h', 'l', 'p', 'r', 'u', 'w', 'e', 'f', 'g', 'n', 'p', 'r', 'u', 'c', 'e', 'h', 'n', 'p', 'r', 'u', 'b', 'c', 'e', 'f', 'h', 'l', 'n', 'p', 'r', 'u', 'w', 'x', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'p', 'r', 'w', 'c', 'e', 'f', 'g', 'h', 'k', 'l', 'n', 'p', 'r', 'u', 'w', 'b', 'c', 'n', 'r', 'u', 'e', 'f', 'g', 'h', 'k', 'l', 'n', 'p', 'r', 'w', 'z', 'c', 'e', 'g', 'h', 'p', 'r', 'u', 'v', 'w', 'b', 'c', 'e', 'k', 'n', 'r', 'u', 'v', 'w', 'b', 'e', 'g', 'l', 'n', 'p', 'r', 'u', 'b', 'c', 'e', 'g', 'h', 'l', 'p', 'r', 'v', 'w', 'c', 'e', 'f', 'h', 'n', 'r', 'u', 'c', 'e', 'f', 'g', 'h', 'n', 'p', 'r', 'u', 'e', 'g', 'h', 'l', 'p', 'r', 'w', 'c', 'e', 'g', 'n', 'p', 'r', 'u', 'w', 'c', 'e', 'f', 'g', 'h', 'n', 'r', 'u', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'v', 'w', 'e', 'g', 'h', 'n', 'p', 'r', 'w', 'b', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'w', 'c', 'h', 'n', 'p', 'r', 'v', 'w', 'b', 'e', 'g', 'h', 'n', 'r', 'w', 'z', 'b', 'c', 'e', 'f', 'g', 'n', 'p', 'r', 'u', 'v', 'c', 'e', 'g', 'h', 'n', 'r', 'u', 'w', 'b', 'c', 'e', 'h', 'n', 'r', 'u', 'w', 'b', 'c', 'e', 'h', 'n', 'q', 'r', 'u', 'w', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'p', 'r', 'u', 'v', 'w', 'c', 'e', 'f', 'h', 'r', 'u', 'v', 'w', 'x', 'c', 'e', 'g', 'h', 'n', 'r', 'u', 'b', 'c', 'e', 'g', 'h', 'n', 'r', 'u', 'w', 'x', 'b', 'c', 'e', 'f', 'g', 'h', 'l', 'n', 'r', 'w', 'b', 'e', 'h', 'u', 'w', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'w', 'x', 'c', 'e', 'h', 'l', 'n', 'p', 'u', 'w', 'z', 'b', 'e', 'g', 'h', 'n', 'r', 'u', 'e', 'f', 'g', 'h', 'l', 'n', 'r', 'u', 'w', 'e', 'g', 'h', 'l', 'n', 'r', 'u', 'w', 'c', 'e', 'f', 'g', 'h', 'n', 'r', 'u', 'v', 'b', 'c', 'e', 'h', 'l', 'n', 'p', 'r', 'u', 'v', 'w', 'c', 'e', 'g', 'h', 'l', 'n', 'p', 'w', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'c', 'e', 'g', 'h', 'l', 'n', 'p', 'w', 'c', 'e', 'f', 'h', 'n', 'r', 'v', 'w', 'b', 'c', 'e', 'f', 'h', 'l', 'n', 'r', 'u', 'v', 'w']

# %%
# Example data
patterns = [
    "How can I manage my time effectively?",
    "What are some good time management tips?",
    "How do I balance my studies and free time?"
]

# Preprocess words
all_words = preprocess_words(patterns, stop_words, punctuation, ignore_list)

# Output the processed words
print(all_words)
# Out:
# ['balance', 'effectively', 'free', 'good', 'manage', 'management', 'study', 'time', 'tip']
